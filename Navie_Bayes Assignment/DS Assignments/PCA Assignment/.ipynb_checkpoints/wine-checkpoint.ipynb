# %% [markdown]
# ##### Write about the benefits/impact of the solution - in what way does the business (client) benefit from the solution provided
#
# ###
# Problem Statement:
#
# Perform hierarchical and K-means clustering on the dataset. After that, perform PCA on the dataset and extract the first 3 principal components and make a new dataset with these 3 principal components as the columns. Now, on this new dataset, perform hierarchical and K-means clustering. Compare the results of clustering on the original dataset and clustering on the principal components dataset (use the scree plot technique to obtain the optimum number of clusters in K-means clustering and check if you’re getting similar results with and without PCA).

# %% [markdown]
# Business Objective:
# The goal of this dataset is to develop a predictive model that classifies wines based on their chemical attributes. This model can assist wine producers or distributors in efficiently categorizing wines, improving quality assurance, maintaining consistency, and enhancing targeted marketing efforts.

# %% [markdown]
# Constraints:
# Data Quality: Ensure that the dataset is clean, with no missing or erroneous values.
#
# Model Accuracy: The model should be highly accurate in predicting wine types to avoid misclassification, which could lead to incorrect labeling and marketing.
#
# Interpretability: Since the chemical properties of wine are highly specialized, it is crucial for the model to provide insights into which features contribute most to the classification.
#
# Scalability: The model should handle large datasets in the future as more wine varieties and data points are collected.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("wine.csv")
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
#      Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# 0             0.28             2.29   5.64  1.04      3.92     1065
# 1             0.26             1.28   4.38  1.05      3.40     1050
# 2             0.30             2.81   5.68  1.03      3.17     1185
# 3             0.24             2.18   7.80  0.86      3.45     1480
# 4             0.39             1.82   4.32  1.04      2.93      735
# ..             ...              ...    ...   ...       ...      ...
# 173           0.52             1.06   7.70  0.64      1.74      740
# 174           0.43             1.41   7.30  0.70      1.56      750
# 175           0.43             1.35  10.20  0.59      1.56      835
# 176           0.53             1.46   9.30  0.60      1.62      840
# 177           0.56             1.35   9.20  0.61      1.60      560
#
# [178 rows x 14 columns]

# %%
df.head()
# Out:
#    Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0     1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1     1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2     1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3     1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4     1    13.24   2.59  2.87        21.0        118     2.80        2.69
#
#    Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# 0           0.28             2.29   5.64  1.04      3.92     1065
# 1           0.26             1.28   4.38  1.05      3.40     1050
# 2           0.30             2.81   5.68  1.03      3.17     1185
# 3           0.24             2.18   7.80  0.86      3.45     1480
# 4           0.39             1.82   4.32  1.04      2.93      735

# %%
df.columns
# Out:
# Index(['Type', 'Alcohol', 'Malic', 'Ash', 'Alcalinity', 'Magnesium', 'Phenols',
#        'Flavanoids', 'Nonflavanoids', 'Proanthocyanins', 'Color', 'Hue',
#        'Dilution', 'Proline'],
#       dtype='object')

# %%
#Count null values
df.isnull().sum()
##There are no null values.
# Out:
# Type               0
# Alcohol            0
# Malic              0
# Ash                0
# Alcalinity         0
# Magnesium          0
# Phenols            0
# Flavanoids         0
# Nonflavanoids      0
# Proanthocyanins    0
# Color              0
# Hue                0
# Dilution           0
# Proline            0
# dtype: int64

# %%
#Now we have to check the outllier.
##Outliers are data points that differ significantly from the majority of the data in a dataset
df.describe()
# Out:
#              Type     Alcohol       Malic         Ash  Alcalinity   Magnesium  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoids  Proanthocyanins       Color  \
# count  178.000000  178.000000     178.000000       178.000000  178.000000
# mean     2.295112    2.029270       0.361854         1.590899    5.058090
# std      0.625851    0.998859       0.124453         0.572359    2.318286
# min      0.980000    0.340000       0.130000         0.410000    1.280000
# 25%      1.742500    1.205000       0.270000         1.250000    3.220000
# 50%      2.355000    2.135000       0.340000         1.555000    4.690000
# 75%      2.800000    2.875000       0.437500         1.950000    6.200000
# max      3.880000    5.080000       0.660000         3.580000   13.000000
#
#               Hue    Dilution      Proline
# count  178.000000  178.000000   178.000000
# mean     0.957449    2.611685   746.893258
# std      0.228572    0.709990   314.907474
# min      0.480000    1.270000   278.000000
# 25%      0.782500    1.937500   500.500000
# 50%      0.965000    2.780000   673.500000
# 75%      1.120000    3.170000   985.000000
# max      1.710000    4.000000  1680.000000

# %%
#Now we will plot boxplot.
import seaborn as sns
sns.boxplot(df[['Ash','Phenols','Color']])
# Out:
# <Axes: >

# %%
outliers_columns=['Malic', 'Ash', 'Alcalinity', 'Magnesium','Proanthocyanins', 'Color', 'Hue']

# %%
import numpy as np
for column in outliers_columns:
    df[column]=np.log1p(df[column])

# %%
df.head()
# Out:
#    Type  Alcohol     Malic       Ash  Alcalinity  Magnesium  Phenols  \
# 0     1    14.23  0.996949  1.232560    2.809403   4.852030     2.80
# 1     1    13.20  1.022451  1.144223    2.501436   4.615121     2.65
# 2     1    13.16  1.211941  1.300192    2.975530   4.624973     2.80
# 3     1    14.37  1.081805  1.252763    2.879198   4.736198     3.85
# 4     1    13.24  1.278152  1.353255    3.091042   4.779123     2.80
#
#    Flavanoids  Nonflavanoids  Proanthocyanins     Color       Hue  Dilution  \
# 0        3.06           0.28         1.190888  1.893112  0.712950      3.92
# 1        2.76           0.26         0.824175  1.682688  0.717840      3.40
# 2        3.24           0.30         1.337629  1.899118  0.708036      3.17
# 3        3.49           0.24         1.156881  2.174752  0.620576      3.45
# 4        2.69           0.39         1.036737  1.671473  0.712950      2.93
#
#    Proline
# 0     1065
# 1     1050
# 2     1185
# 3     1480
# 4      735

# %%
sns.boxplot(df[['Phenols','Flavanoids']])
# Out:
# <Axes: >

# %% [markdown]
#  #### Normalize the data

# %%
from sklearn.preprocessing import StandardScaler
Scale=StandardScaler()
df_scaled=Scale.fit_transform(df)

# %%
df_scaled=pd.DataFrame(df_scaled, columns=df.columns)

# %%
sns.boxplot(df_scaled)
# Out:
# <Axes: >

# %% [markdown]
# Hierarchical clustering on normalized data

# %%
#perform clustering based on alcohol content
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt

# %%
#hierarchical clustering
Clust=AgglomerativeClustering(n_clusters=3)
y_clust=Clust.fit_predict(df_scaled)

# %%
#create dataframes for different clusters
df_cluster1=df[y_clust==0]
df_cluster2=df[y_clust==1]
df_cluster3=df[y_clust==2]

plt.scatter(df_cluster1['Phenols'], df_cluster1['Flavanoids'], s=50, c='blue', label='Cluster 1')
plt.scatter(df_cluster2['Phenols'], df_cluster2['Flavanoids'], s=50, c='red', label='Cluster 2')
plt.scatter(df_cluster3['Phenols'], df_cluster3['Flavanoids'], s=50, c='yellow', label='Cluster 3')

# %% [markdown]
# KMeans Clustering on normalized Data

# %%
#Perform K-means clustering based on Phenols and Flavanoids acid
# Perform K-means clustering based on alcohol and malic acid
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3, random_state=42)
y_kmeans = kmeans.fit_predict(df_scaled[['Alcohol', 'Malic']])


#Get cluster centers (centroids)
centriods = kmeans.cluster_centers_ 

#Create dataframes for different clusters
df_cluster1 = df_scaled[y_Kmeans == 0]
df_cluster1 = df_scaled[y_Kmeans == 1]
df_cluster1 = df_scaled[y_Kmeans == 2]

#Plot the clusters and centroids
plt.scatter(df_cluster1['Phenols'], df_cluster1['Flavanoids'], s=50, c='red', label='Cluster 1')
plt.scatter(df_cluster1['Phenols'], df_cluster1['Flavanoids'], s=50, c='yellow', label='Cluster 2')
plt.scatter(df_cluster1['Phenols'], df_cluster1['Flavanoids'], s=50, c='blue', label='Cluster 3')
plt.scatter(centroids[:,0],centroids[:,1],marker='*', s=200, c='black', label='Centroids')
plt.xlabel('Phenols')
plt.ylabel('Flavanoids')
plt.title('k-means Clustering on Wine Phenols Vs Flavanoids')
plt.legend()
plt.show()
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 12
#       9 centriods = kmeans.cluster_centers_
#      11 #Create dataframes for different clusters
# ---> 12 df_cluster1 = df_scaled[y_Kmeans == 0]
#      13 df_cluster1 = df_scaled[y_Kmeans == 1]
#      14 df_cluster1 = df_scaled[y_Kmeans == 2]
#
# NameError: name 'y_Kmeans' is not defined

# %%
# Perform K-means clustering based on alcohol and malic acid
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3, random_state=42)
y_kmeans = kmeans.fit_predict(df_scaled[['Phenols', 'Flavanoids']])

# Get cluster centers (centroids)
centroids = kmeans.cluster_centers_

# Create dataframes for different clusters
df_cluster1 = df_scaled[y_kmeans == 0]
df_cluster2 = df_scaled[y_kmeans == 1]
df_cluster3 = df_scaled[y_kmeans == 2]

# Plot the clusters and centroids
plt.scatter(df_cluster1['Phenols'], df_cluster1['Flavanoids'], s=50, c='red', label='Cluster 1')
plt.scatter(df_cluster2['Phenols'], df_cluster2['Flavanoids'], s=50, c='blue', label='Cluster 2')
plt.scatter(df_cluster3['Phenols'], df_cluster3['Flavanoids'], s=50, c='yellow', label='Cluster 3')
plt.scatter(centroids[:, 0], centroids[:, 1], marker='*', s=200, c='black', label='Centroids')
plt.xlabel('Phenols')
plt.ylabel('Flavanoids')
plt.title('K-means Clustering Wine(Phenols & Flavanoids)')
plt.legend()
plt.show()
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# Perform K-means clustering based on alcohol and malic acid
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3, random_state=42)
y_kmeans = kmeans.fit_predict(df_scaled[['Alcohol', 'Malic']])

# Get cluster centers (centroids)
centroids = kmeans.cluster_centers_

# Create dataframes for different clusters
df_cluster1 = df_scaled[y_kmeans == 0]
df_cluster2 = df_scaled[y_kmeans == 1]
df_cluster3 = df_scaled[y_kmeans == 2]

# Plot the clusters and centroids
plt.scatter(df_cluster1['Alcohol'], df_cluster1['Malic'], s=50, c='blue', label='Cluster 1')
plt.scatter(df_cluster2['Alcohol'], df_cluster2['Malic'], s=50, c='red', label='Cluster 2')
plt.scatter(df_cluster3['Alcohol'], df_cluster3['Malic'], s=50, c='yellow', label='Cluster 3')
plt.scatter(centroids[:, 0], centroids[:, 1], marker='*', s=200, c='black', label='Centroids')
plt.xlabel('Alcohol')
plt.ylabel('Malic Acid')
plt.title('K-means Clustering Wine(Alcohol vs Malic Acid)')
plt.legend()
plt.show()
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
from sklearn.metrics import davies_bouldin_score

# Calculate Davies-Bouldin Index
db_index = davies_bouldin_score(df_scaled, y_kmeans)
print(f'Davies-Bouldin Index: {db_index}')
# Out:
# Davies-Bouldin Index: 1.7602456300204243

# %%
#calculate silhoutte score average
from sklearn.metrics import silhouette_score
sil_score=silhouette_score(df_scaled, y_kmeans)
print(sil_score)
# Out:
# 0.19206570700265838

# %% [markdown]
# Principle Component Analysis

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
principal_components = pca.fit_transform(df_scaled)
# Create a new DataFrame with the principal components
principal_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2', 'PC3'])
# Print the explained variance ratio for each component
print('Explained Variance Ratio:', pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio: [0.3969738  0.18849543 0.10325767]

# %%
#perform kmeans clustering on PC1 and PC2
kmeans = KMeans(n_clusters=3, random_state=42)
y_kmeans = kmeans.fit_predict(principal_df[['PC1', 'PC2']])
# Get cluster centers (centroids)
centroids = kmeans.cluster_centers_
# Create dataframes for different clusters
df_cluster1 = principal_df[y_kmeans == 0]
df_cluster2 = principal_df[y_kmeans == 1]
df_cluster3 = principal_df[y_kmeans == 2]
# Plot the clusters and centroids
plt.scatter(df_cluster1['PC1'], df_cluster1['PC2'], s=50, c='red', label='Cluster 1')
plt.scatter(df_cluster2['PC1'], df_cluster2['PC2'], s=50, c='yellow', label='Cluster 2')
plt.scatter(df_cluster3['PC1'], df_cluster3['PC2'], s=50, c='orange', label='Cluster 3')
plt.scatter(centroids[:, 0], centroids[:, 1], marker='*', s=200, c='black', label='Centroids')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('K-means Clustering of Wine Dataset (PC1 vs PC2)')
plt.legend()
plt.show()
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
#perform kmeans clustering on PC1 and PC2
kmeans = KMeans(n_clusters=3, random_state=42)
y_kmeans = kmeans.fit_predict(principal_df[['PC2', 'PC3']])
# Get cluster centers (centroids)
centroids = kmeans.cluster_centers_
# Create dataframes for different clusters
df_cluster1 = principal_df[y_kmeans == 0]
df_cluster2 = principal_df[y_kmeans == 1]
df_cluster3 = principal_df[y_kmeans == 2]
# Plot the clusters and centroids
plt.scatter(df_cluster1['PC2'], df_cluster1['PC3'], s=50, c='red', label='Cluster 1')
plt.scatter(df_cluster2['PC2'], df_cluster2['PC3'], s=50, c='yellow', label='Cluster 2')
plt.scatter(df_cluster3['PC2'], df_cluster3['PC3'], s=50, c='orange', label='Cluster 3')
plt.scatter(centroids[:, 0], centroids[:, 1], marker='*', s=200, c='black', label='Centroids')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('K-means Clustering of Wine Dataset (PC2 vs PC3)')
plt.legend()
plt.show()
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
#perform kmeans clustering on PC1 and PC2
kmeans = KMeans(n_clusters=3, random_state=42)
y_kmeans = kmeans.fit_predict(principal_df[['PC1', 'PC2']])
# Get cluster centers (centroids)
centroids = kmeans.cluster_centers_
# Create dataframes for different clusters
df_cluster1 = principal_df[y_kmeans == 0]
df_cluster2 = principal_df[y_kmeans == 1]
df_cluster3 = principal_df[y_kmeans == 2]
# Plot the clusters and centroids
plt.scatter(df_cluster1['PC1'], df_cluster1['PC3'], s=50, c='red', label='Cluster 1')
plt.scatter(df_cluster2['PC1'], df_cluster2['PC3'], s=50, c='yellow', label='Cluster 2')
plt.scatter(df_cluster3['PC1'], df_cluster3['PC3'], s=50, c='orange', label='Cluster 3')
plt.scatter(centroids[:, 0], centroids[:, 1], marker='*', s=200, c='black', label='Centroids')
plt.xlabel('PC1')
plt.ylabel('PC3')
plt.title('K-means Clustering of Wine Dataset (PC1 vs PC3)')
plt.legend()
plt.show()
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
from sklearn.metrics import davies_bouldin_score

# Calculate Davies-Bouldin Index
db_index = davies_bouldin_score(df_scaled, y_kmeans)
print(f'Davies-Bouldin Index: {db_index}')
# Out:
# Davies-Bouldin Index: 1.2813876517082854

# %%
#calculate silhoutte score average
from sklearn.metrics import silhouette_score
sil_score=silhouette_score(principal_df, y_kmeans)
print(sil_score)
# Out:
# 0.5020153562476473
