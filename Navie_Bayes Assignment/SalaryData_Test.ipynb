# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("SalaryData_Train.csv")

# %%
df.sample(4)
# Out:
#        age          workclass      education  educationno  \
# 14383   43            Private   Some-college           10
# 3434    27            Private        HS-grad            9
# 29248   57   Self-emp-not-inc      Doctorate           16
# 5097    45            Private   Some-college           10
#
#                 maritalstatus     occupation    relationship    race      sex  \
# 14383                Divorced          Sales       Unmarried   White   Female
# 3434       Married-civ-spouse   Craft-repair         Husband   White     Male
# 29248      Married-civ-spouse          Sales         Husband   White     Male
# 5097    Married-spouse-absent   Adm-clerical   Not-in-family   White   Female
#
#        capitalgain  capitalloss  hoursperweek          native  Salary
# 14383            0            0            55   United-States    >50K
# 3434             0            0            40   United-States   <=50K
# 29248            0         1902            40   United-States    >50K
# 5097             0            0            40   United-States   <=50K

# %%
df.shape
# Out:
# (30161, 14)

# %%
test_df=pd.read_csv('SalaryData_Test.csv')

# %%
test_df.sample(4)
# Out:
#        age   workclass      education  educationno        maritalstatus  \
# 14443   48   Local-gov   Some-college           10   Married-civ-spouse
# 7862    42     Private        HS-grad            9   Married-civ-spouse
# 12131   17     Private           11th            7        Never-married
# 3225    29     Private        HS-grad            9   Married-civ-spouse
#
#                occupation relationship    race      sex  capitalgain  \
# 14443      Prof-specialty      Husband   White     Male            0
# 7862    Machine-op-inspct      Husband   White     Male            0
# 12131               Sales    Own-child   White   Female            0
# 3225    Machine-op-inspct      Husband   White     Male            0
#
#        capitalloss  hoursperweek          native  Salary
# 14443            0            40   United-States    >50K
# 7862             0            40   United-States   <=50K
# 12131            0            24   United-States   <=50K
# 3225             0            40   United-States   <=50K

# %%
test_df.shape
# Out:
# (15060, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
def set_of_data(col) : 
    return len(set(df[col]))

# %%
for i in df.columns: 
    print(f"{i} ----> {set_of_data(i)}")
# Out:
# age ----> 72
# workclass ----> 7
# education ----> 16
# educationno ----> 16
# maritalstatus ----> 7
# occupation ----> 14
# relationship ----> 6
# race ----> 5
# sex ----> 2
# capitalgain ----> 118
# capitalloss ----> 90
# hoursperweek ----> 94
# native ----> 40
# Salary ----> 2

# %%
# target colums is Salary

# %%
sns.scatterplot(df,x='age',y='capitalgain',hue='Salary')
# Out:
# <Axes: xlabel='age', ylabel='capitalgain'>

# %%
sns.scatterplot(df,x='age',y='capitalloss',hue='Salary')
# Out:
# <Axes: xlabel='age', ylabel='capitalloss'>
