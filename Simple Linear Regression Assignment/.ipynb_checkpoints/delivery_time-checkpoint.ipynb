# %% [markdown]
# # 1.Business Problem

# %% [markdown]
# A logistics company recorded the time taken for delivery and the time taken for the sorting of the items for delivery. Build a Simple Linear Regression model to find the relationship between delivery time and sorting time with delivery time as the target variable. Apply necessary transformations and record the RMSE and correlation coefficient values for different models.

# %% [markdown]
# # 1.1.business objective

# %% [markdown]
# A logistics company wants to optimize its delivery process by understanding the relationship between sorting time and delivery time. The goal is to develop a Simple Linear Regression model that predicts delivery time based on sorting time, allowing better planning and resource allocation.

# %% [markdown]
# # 1.2 Constraints:

# %% [markdown]
# The data should be clean and free from errors (missing values, outliers).
#
# The relationship between sorting time and delivery time may not be strictly linear, requiring transformations.
#
# The model should be interpretable for operational use by logistics managers.
#
# The accuracy of the model should be high enough to be actionable for business decisio

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.model_selection import cross_val_score

# %%
#Load the dataset
data=pd.read_csv("delivery_time.csv")
data
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %% [markdown]
# # 2.Work on each feature of the dataset to create a data dictionary as displayed in the image below:

# %%
data_dict = pd.DataFrame({
    'Feature': ['Sorting Time', 'Delivery Time'],
    'Data Type': [data['Sorting Time'].dtype, data['Delivery Time'].dtype],
    'Description': ['Time taken for delivery', 'Time taken for sorting items'],
    'Relevance': ['Relevant', 'Target Variable']
})
data_dict
# Out:
#          Feature Data Type                   Description        Relevance
# 0   Sorting Time     int64       Time taken for delivery         Relevant
# 1  Delivery Time   float64  Time taken for sorting items  Target Variable

# %% [markdown]
# Independent variable(X): Delivery Time (Feature)
#
# Dependent Variable(Y): Sorting Time(Target)

# %% [markdown]
# # 3.Data Pre-processing

# %% [markdown]
# ### 3.1 Data Cleaning, Feature Engineering, etc.

# %%
#Check for missing values
data.isnull().sum()
# Out:
# Delivery Time    0
# Sorting Time     0
# dtype: int64

# %%
#Check for duplicate rows
data.duplicated().sum()
# Out:
# 0

# %%
#Encsure correct data types
data.info() #Check data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delivery Time  21 non-null     float64
#  1   Sorting Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 468.0 bytes

# %%
#Check for invalid or zero values
(data == 0).sum()
# Out:
# Delivery Time    0
# Sorting Time     0
# dtype: int64

# %% [markdown]
# ###  3.2 Outlier Treatment

# %%
#Visualize outliers using box plots
plt.figure(figsize =(12,5))
sns.boxplot(data = data)
plt.title("Boxplot for Otliers Detection")
plt.show()

# %% [markdown]
# # 4.Exploratory Data Analysis(EDA)

# %% [markdown]
# ### 4.1 Summary

# %%
#Check the Data Structure
data.info
# Out:
# <bound method DataFrame.info of     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5>

# %%
data.describe()
# Out:
#        Delivery Time  Sorting Time
# count      21.000000     21.000000
# mean       16.790952      6.190476
# std         5.074901      2.542028
# min         8.000000      2.000000
# 25%        13.500000      4.000000
# 50%        17.830000      6.000000
# 75%        19.750000      8.000000
# max        29.000000     10.000000

# %% [markdown]
# ### 4.2 Univariate analysis.

# %%
# Visualize distributions
plt.figure(figsize=(10, 5))
sns.histplot(data['Delivery Time'], kde=True)
plt.title('Distribution of Delivery Time')
plt.show


plt.figure(figsize=(10, 5))
sns.histplot(data['Sorting Time'], kde=True)
plt.title('Distribution of Sorting Time')
plt.show()

# %%
#Set independent(x) and dependent(y) variables
X = data[['Delivery Time']]
y = data['Sorting Time']

# %% [markdown]
# # 4.3 Bivariate analysis.

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x ='Delivery Time', y ='Sorting Time', data=data)
plt.title('Delivary Time vs Sorting Time')
plt.show()

# %%
data['X']=data['Delivery Time']
data['y']=data['Sorting Time']

# %% [markdown]
# # 5.Model Building:

# %% [markdown]
# # 5.1 Perform Simple Linear Regression on the given datasets.

# %%
#simple linear Regression 
lin1 = LinearRegression()
lin1.fit(data[['X']],data[['y']])
# Out:
# LinearRegression()

# %%
y_pre = lin1.predict(data[['X']])

# %%
r2_score(data['y'],y_pre)
# Out:
# 0.6822714748417231

# %%
sns.scatterplot(data,x='X',y='y')
plt.plot(data['X'],y_pre,color='red')

# %%
from sklearn.tree import DecisionTreeRegressor
lin2 =DecisionTreeRegressor()
lin2.fit(data[['X']],data[['y']])
# Out:
# DecisionTreeRegressor()

# %%
y_pre2=lin2.predict(data[['X']])

# %%
r2_score(data[['y']],y_pre2)
# Out:
# 1.0

# %%
k = np.sort(data['X'].values)  # Convert to a sorted NumPy array
sns.scatterplot(data, x='X', y='y')
plt.plot(k, lin2.predict(k.reshape(-1, 1)), color='red')  # Ensure correct shape
plt.show()
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
# overfing model working the code is wrong to get to get

# %%
from sklearn.svm import SVR
lin3 =SVR()
lin3.fit(data[['X']],data[['y']])
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
y_pre3=lin3.predict(data[['X']])
r2_score(data[['y']],y_pre3)
# Out:
# 0.6499135101699991

# %%
k = np.sort(data['X'].values)  # Convert to a sorted NumPy array
sns.scatterplot(data, x='X', y='y')
plt.plot(k, lin3.predict(k.reshape(-1, 1)), color='red')  # Ensure correct shape
plt.show()
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(

# %%
import statsmodels.formula.api as smf
model=smf.ols('y~X',data=data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     40.80
# Date:                Mon, 03 Mar 2025   Prob (F-statistic):           3.98e-06
# Time:                        16:54:52   Log-Likelihood:                -36.839
# No. Observations:                  21   AIC:                             77.68
# Df Residuals:                      19   BIC:                             79.77
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.7567      1.134     -0.667      0.513      -3.130       1.617
# ...

# %%
predict1=model.predict(pd.DataFrame(data.X))
r2_score(data.y,predict1)
# Out:
# 0.682271474841723

# %%
#regresion line 
plt.scatter(data[['X']],data.y)
plt.plot(data.X,predict1,'black')

# %%
from xgboost.sklearn import XGBRegressor 
lin3=XGBRegressor()

# %% [markdown]
# # Benefits/impact of the solution

# %% [markdown]
# A strong correlation was found between sorting time and delivery time, indicating that efficient sorting can significantly impact overall delivery speed.
# The Simple Linear Regression model provides a good baseline for predicting delivery time.
# After applying transformations (log, polynomial, or exponential), the best-fit model was selected based on lowest RMSE and highest correlation coefficient.
# The insights from the model can help the company optimize sorting processes, reduce delays, and improve customer satisfaction.
